# %% [markdown]
# # 웹 크롤링

# %%
from IPython.display import Image

# %%
import pymysql

# %%
conn = pymysql.connect(
    host='18.117.197.254',
    port=3306, # mysql포트
    user='ssossotable',  # 접속 계정
    password='Mysql7968!', # 루트계정 본인 비번
    db='ssossotable_food',  # 접속하려는 데이터베이스 명
    charset='utf8'
)

# %%
cursor = conn.cursor()
cursor.execute('SELECT name FROM food;')
result = cursor.fetchall()
print(result)
print(result[0])
print(result[0][0])
# Out:
# (('가라아게',), ('가지볶음',), ('가츠동',), ('간장불고기',), ('갈비구이',), ('갈비찜',), ('갈치조림',), ('감자튀김',), ('겉절이',), ('고구마줄기볶음',), ('고기국수',), ('고기만두',), ('고등어조림',), ('고등어초밥',), ('고추바사삭',), ('고추잡채',), ('고추장불고기',), ('광어회',), ('굴국',), ('규동',), ('그릭요거트',), ('김밥',), ('김치볶음밥',), ('김치찌개',), ('까르보나라',), ('깐풍가지',), ('깐풍기',), ('꼬꼬동',), ('꽃게찜',), ('꿔바로우',), ('나가사키짬뽕',), ('니쿠자가',), ('닭가슴살',), ('닭갈비',), ('닭강정',), ('닭발',), ('닭볶음탕',), ('덴뿌라',), ('도넛',), ('돈카츠',), ('동파육',), ('돼지곰탕',), ('돼지곱창(양념)',), ('돼지껍데기',), ('돼지막창',), ('돼지부속',), ('된장찌개',), ('딤섬',), ('딱딱한 복숭아',), ('똠얌꿍',), ('라멘',), ('라면',), ('라무네',), ('레몬',), ('리조또',), ('리코타치즈샐러드',), ('마라샹궈',), ('마라탕',), ('마파두부',), ('막걸리',), ('매운족발',), ('매운탕',), ('맥주',), ('멘보샤',), ('묵은지',), ('물냉면',), ('물렁한 복숭아',), ('미역국',), ('반미',), ('밤고구마',), ('버섯',), ('버섯치즈파니니',), ('버섯크림리조또',), ('버터갈릭감자튀김',), ('버터도너츠',), ('보쌈',), ('볶음밥',), ('분짜',), ('불싸이버거',), ('불쭈꾸미',), ('붕어빵(슈크림)',), ('붕어빵(팥)',), ('브라우니',), ('비빔냉면',), ('비빔밥',), ('빙수',), ('사케',), ('삼겹살',), ('삼겹살구이',), ('삼치구이',), ('새우튀김',), ('샐러드
# ...

# %%
cursor.execute('SELECT COUNT(*) FROM food;')
size = cursor.fetchall()
print(size[0][0])
print(type(size[0][0]))
# Out:
# 188
# <class 'int'>

# %%
food = list()
   
food.append(result)
print(food)
print(food[0][0])
# Out:
# [(('가라아게',), ('가지볶음',), ('가츠동',), ('간장불고기',), ('갈비구이',), ('갈비찜',), ('갈치조림',), ('감자튀김',), ('겉절이',), ('고구마줄기볶음',), ('고기국수',), ('고기만두',), ('고등어조림',), ('고등어초밥',), ('고추바사삭',), ('고추잡채',), ('고추장불고기',), ('광어회',), ('굴국',), ('규동',), ('그릭요거트',), ('김밥',), ('김치볶음밥',), ('김치찌개',), ('까르보나라',), ('깐풍가지',), ('깐풍기',), ('꼬꼬동',), ('꽃게찜',), ('꿔바로우',), ('나가사키짬뽕',), ('니쿠자가',), ('닭가슴살',), ('닭갈비',), ('닭강정',), ('닭발',), ('닭볶음탕',), ('덴뿌라',), ('도넛',), ('돈카츠',), ('동파육',), ('돼지곰탕',), ('돼지곱창(양념)',), ('돼지껍데기',), ('돼지막창',), ('돼지부속',), ('된장찌개',), ('딤섬',), ('딱딱한 복숭아',), ('똠얌꿍',), ('라멘',), ('라면',), ('라무네',), ('레몬',), ('리조또',), ('리코타치즈샐러드',), ('마라샹궈',), ('마라탕',), ('마파두부',), ('막걸리',), ('매운족발',), ('매운탕',), ('맥주',), ('멘보샤',), ('묵은지',), ('물냉면',), ('물렁한 복숭아',), ('미역국',), ('반미',), ('밤고구마',), ('버섯',), ('버섯치즈파니니',), ('버섯크림리조또',), ('버터갈릭감자튀김',), ('버터도너츠',), ('보쌈',), ('볶음밥',), ('분짜',), ('불싸이버거',), ('불쭈꾸미',), ('붕어빵(슈크림)',), ('붕어빵(팥)',), ('브라우니',), ('비빔냉면',), ('비빔밥',), ('빙수',), ('사케',), ('삼겹살',), ('삼겹살구이',), ('삼치구이',), ('새우튀김',), ('샐러
# ...

# %% [markdown]
# ## 1. HTML 셀렉터

# %% [markdown]
# ![selector](http://ssossotable.com/sample_src/selector.PNG)

# %% [markdown]
# ### 1. tag
# - HTML 태그
# - h1, img, input, div...
#
# ### 2. id
# - 유일성이 있는 셀렉터
# - ***중복되어서는 안 됨***
# - samsaek, dodo, moo...
#
# ### 3. class
# - 다양한 객체가 공통된 클래스를 가질 수 있다
# - ***중복 가능***
# - cat, samsaek-family...

# %% [markdown]
# # 2. Selenium을 이용한 웹 크롤링

# %% [markdown]
# ### 2.1 셀레니움 설치

# %% [markdown]
# - 크롬용 웹드라이버 설치(다른 브라우저도 가능)
#
# https://chromedriver.chromium.org/downloads

# %% [markdown]
# ### 2.2 필요 모듈 설치
# - bs4, selenium, webdriver_manager 설치

# %%
# 크롤링 관련 모듈
from bs4 import BeautifulSoup 
from selenium import webdriver
from selenium.webdriver.common.by import By 
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

import time

# %%
driver=None

# %%
# 드라이버 세팅 함수
def set_chrome_driver():
    global driver
    if driver is None:
        chrome_options = webdriver.ChromeOptions()
        return webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)
    else:
        return driver

# %%
# 드라이버 리셋 함수
def reset_driver():
    global driver
    driver.quit()
    if driver is None:
        pass
    else:
        driver = None

# %% [markdown]
# ### 2.3 셀레니움을 이용한 웹페이지 접속

# %%
# 드라이버 세팅
driver=set_chrome_driver()
# Out:
# [WDM] - Downloading: 100%|████████████████████████████████████████████████████████| 6.46M/6.46M [00:01<00:00, 5.73MB/s]

# %%
URL="https://www.google.co.kr/"
# 타겟 페이지 접속
driver.get(URL)
time.sleep(2)

# %%
driver.find_element(By.XPATH, '/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input').send_keys(food[0][0][0])
#driver.find_element(By.XPATH, '/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input').send_keys(cursor.fetchone()[0])

# %%
driver.find_element(By.XPATH, '/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input').send_keys(webdriver.common.keys.Keys.ENTER)

# %%
driver.find_element(By.XPATH, '//*[@id="hdtb-msb"]/div[1]/div/div[2]/a').send_keys(webdriver.common.keys.Keys.ENTER)

# %%
driver.find_element(By.XPATH, '//*[@id="islrg"]/div[1]/div[1]/a[1]/div[1]/img').click()

# %%
#e=driver.find_elements(By.CLASS_NAME,'rg_i Q4LuWd')
#e0_src=e[0].get_dom_attribute('src')
#Image(e0_src)

e_src=driver.find_element(By.XPATH, '/html/body/div[2]/c-wiz/div[3]/div[2]/div[3]/div/div/div/div[3]/div[2]/c-wiz/div[2]/div[1]/div[1]/div[2]/div/a/img').get_attribute("src")
print(e_src)
Image(e_src)
# Out:
# https://recipe1.ezmember.co.kr/cache/recipe/2016/07/04/ffb4032c6ce70ccdd71fa933ffc054e51.jpg

# %%
print(type(food[0][0])

# %%
print(e_src)
print(food[0][0])
print(food[0][0][0])
cursor = conn.cursor()
cursor.execute('UPDATE food SET image_iyj = %s WHERE name = %s;', (e_src, food[0][0]))
conn.commit()
# Out:
# https://recipe1.ezmember.co.kr/cache/recipe/2016/07/04/ffb4032c6ce70ccdd71fa933ffc054e51.jpg
# ('가라아게',)
# 가라아게

# %%
import random

# %%
print(size)
print(size[0][0])
print(type(size[0][0]))
number = 183
for i in range(size[0][0]-183):
    number += 1
    driver.find_element(By.XPATH, '//*[@id="REsRA"]').clear()
    driver.find_element(By.XPATH, '//*[@id="REsRA"]').send_keys(food[0][number][0])
    driver.find_element(By.XPATH, '//*[@id="REsRA"]').send_keys(webdriver.common.keys.Keys.ENTER)
    time.sleep(random.uniform(1,2))
    #e = driver.find_elements(By.CLASS_NAME,'rg_i.Q4LuWd')
    #e_src=e[0].get_dom_attribute('src')
    driver.find_element(By.XPATH, '//*[@id="islrg"]/div[1]/div[1]/a[1]/div[1]/img').click()
    time.sleep(random.uniform(3,6))
    e_src=driver.find_element(By.XPATH, '//*[@id="Sva75c"]/div/div/div[2]/div[2]/div[2]/c-wiz/div[2]/div[1]/div[1]/div[2]/div/a/img').get_attribute("src")
    print(number)
    print(e_src)
    #time.sleep(random.uniform(3, 6))
    cursor.execute('UPDATE food SET image_iyj = %s WHERE name = %s;', (e_src, food[0][number][0]))
    time.sleep(1)
    #conn.commit()
    #time.sleep(2)
# Out:
# ((188,),)
# 188
# <class 'int'>
# 184
# http://img.choroc.com/newshop/goods/016440/016440_1.jpg
# 185
# https://w.namu.la/s/76f864cc9502421cc76cfd53bfda39db401e40dfc66985eed311e3cc66aaf861937817b320b67e44d40093df65ee78d421e9e0af5ac7c0104a559000be4757be6b99b89a2b9f6c03b115240f7a4bd6f01870eff65980d1e466d51006a375d31055893274d36bf74fd8f7c122ada44a6c
# 186
# https://recipe1.ezmember.co.kr/cache/recipe/2016/06/08/4c8bc166645ac97622382a6bbf9d0ae91.jpg
# 187
# https://w.namu.la/s/760afdd1241b5ae36410dd14b75f16ab8356885d9a74a0d3754ff3938f3e14600e38b023e6f8c55a1300227ea3026d578b8dfc049fd64e29d50032417eaa319890156a633ee547abff7f8c6e715e92a984d4611154aad8d61d784823d447cfb4cd2f3d0c782d53e630c2c2a6bee9621e
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [32], in <cell line: 5>()
#       6 number += 1
#       7 driver.find_element(By.XPATH, '//*[@id="REsRA"]').clear()
# ...

# %%
conn.commit()

# %% [markdown]
# ### 2.3.1 태그로 찾기

# %%
# img tag들을 찾음
e=driver.find_elements(By.TAG_NAME,'img')
e.
print(e)
#e = driver.find_element(By.TITLE, "검색")
#e_src = get_dom_attribute()
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="5f3c8078d12fa2fbc419d56216167016", element="bec514ae-7211-4aee-b0b5-d6dddeae4669")>, <selenium.webdriver.remote.webelement.WebElement (session="5f3c8078d12fa2fbc419d56216167016", element="3ffcd852-8279-424d-a91d-e4d5747e47af")>, <selenium.webdriver.remote.webelement.WebElement (session="5f3c8078d12fa2fbc419d56216167016", element="ade83216-e140-4acf-891e-c80f35b7e33a")>, <selenium.webdriver.remote.webelement.WebElement (session="5f3c8078d12fa2fbc419d56216167016", element="6e563ee4-5401-4db6-986e-5c3e0ede86ff")>, <selenium.webdriver.remote.webelement.WebElement (session="5f3c8078d12fa2fbc419d56216167016", element="0f5ddbaa-0b5c-409a-8d17-db227c7cadd2")>, <selenium.webdriver.remote.webelement.WebElement (session="5f3c8078d12fa2fbc419d56216167016", element="e59a6bdc-896c-4ddd-8639-5e3377a8d913")>]

# %%
e0=e[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [25], in <cell line: 1>()
# ----> 1 e0=e[0]
#
# TypeError: 'WebElement' object is not subscriptable

# %%
# 첫 번째 img태그의 src를 가져옴
e0_src=e[0].

# %%
# 이미지 메타데이터
e0_src
# Out:
# 'http://ssossotable.com/sample_src/samsaek.jpeg'

# %%
Image(e0_src)

# %% [markdown]
# ### 2.3.2 클래스로 찾기

# %%
# samsaek-family 클래스들을 찾음
e=driver.find_elements(By.CLASS_NAME,'samsaek-family')

# %%
e1_src=e[1].get_dom_attribute('src')

# %%
Image(e1_src)

# %% [markdown]
# ### 2.3.3 id로 찾기

# %%
# dodo id를 찾음
e=driver.find_element(By.ID,'moo')

# %%
e_src=e.get_dom_attribute('src')

# %%
Image(e_src)

# %%
reset_driver()

# %% [markdown]
# # TODO
#
# 1. 하나의 웹 페이지를 선택하세요
# 2. 해당 웹 페이지에서 음식 이름을 검색하여 나오는 이미지들을 크롤링하세요
#     - pymysql을 통한 DB연동
#     - food 테이블에서 음식 이름 가져오기
#     - 음식 이름을 통한 검색
#     - 음식 사진 메타데이터 획득
#     - 해당 음식 사진 메타데이터를 DB에 update
# 3. 해당 과정을 DB의 모든 음식 데이터에 대해 반복하세요
#
# ### 참조
# 1. http://ssossotable.com/sample.html
# - 크롤링 예제 페이지
# 2. http://ssossotable.com/image_sample.html
# - 이미지 출력 페이지
# - db에 update 후 해당 페이지에서 출력 확인
